# %%
import os
import torch
from PIL import Image
import torch.nn.functional as F

from watermark_anything.data.metrics import msg_predict_inference
from notebooks.inference_utils import (
    load_model_from_checkpoint, 
    default_transform, 
    msg2str,
    multiwm_dbscan
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the model
exp_dir = "checkpoints"
json_path = os.path.join(exp_dir, "params.json")
ckpt_path = os.path.join(exp_dir, 'wam_mit.pth')
wam = load_model_from_checkpoint(json_path, ckpt_path).to(device).eval()

# DBSCAN parameters
epsilon = 1
min_samples = 700

# Configuration
output_dir = "outputs_H"
multi_watermark_dir = os.path.join(output_dir, "multi_watermarked")

# List all multi-watermarked images
wm_files = [f for f in os.listdir(multi_watermark_dir) if f.endswith('_multi_wm.png')]

print(f"Found {len(wm_files)} multi-watermarked images in {multi_watermark_dir}")
print(f"DBSCAN parameters: epsilon={epsilon}, min_samples={min_samples}")
print("-" * 80)
# Out:
# making attention of type 'vanilla' with 64 in_channels
# Working with z of shape (1, 68, 32, 32) = 69632 dimensions.
# making attention of type 'vanilla' with 64 in_channels
# Model loaded successfully from checkpoints/wam_mit.pth
# {'embedder_config': 'configs/embedder.yaml', 'augmentation_config': 'configs/all_augs_multi_wm.yaml', 'extractor_config': 'configs/extractor.yaml', 'attenuation_config': 'configs/attenuation.yaml', 'embedder_model': 'vae_small', 'extractor_model': 'sam_base', 'nbits': 32, 'img_size': 256, 'img_size_extractor': 256, 'attenuation': 'jnd_1_3_blue', 'scaling_w': 2.0, 'scaling_w_schedule': None, 'scaling_i': 1.0, 'roll_probability': 0.2, 'multiple_w': 1.0, 'nb_wm_eval': 5, 'optimizer': 'AdamW,lr=1e-4', 'optimizer_d': None, 'scheduler': 'CosineLRScheduler,lr_min=1e-6,t_initial=100,warmup_lr_init=1e-6,warmup_t=5', 'epochs': 200, 'batch_size': 8, 'batch_size_eval': 16, 'temperature': 1.0, 'workers': 8, 'to_freeze_embedder': None, 'lambda_w': 1.0, 'lambda_w2': 6.0, 'lambda_i': 0.0, 'lambda_d': 0.0, 'balanced': True, 'total_gnorm': 0.0, 'perceptual_loss': 'none', 'disc_start': 0, 'disc_num_layers': 2, 'only_eval': False, 'eval_freq': 5, 'saveimg_freq': 5, 'saveckpt_freq': 50, 'seed': 42, 'debug_slurm': False, 'local_rank': 0, 'master_port': 18482, 'is_slurm_job': True, 'n_nodes': 1, 'node_id': 0, 'global_rank': 0, 'world_size': 8, 'n_gpu_per_node': 8, 'is_master': True, 'multi_node': False, 'distributed': True}
# Found 700 multi-watermarked images in outputs_H/multi_watermarked
# DBSCAN parameters: epsilon=1, min_samples=700
# --------------------------------------------------------------------------------

# %%
for wm_file in wm_files:
    wm_path = os.path.join(multi_watermark_dir, wm_file)
    
    # Load the watermarked image
    img = Image.open(wm_path).convert("RGB")
    img_tensor = default_transform(img).unsqueeze(0).to(device)
    
    # Detect watermarks
    preds = wam.detect(img_tensor)["preds"]
    mask_preds = F.sigmoid(preds[:, 0, :, :])
    bit_preds = preds[:, 1:, :, :]
    
    # Use DBSCAN to find multiple watermarks
    centroids, positions = multiwm_dbscan(bit_preds, mask_preds, epsilon=epsilon, min_samples=min_samples)
    
    print(f"{wm_file}: Found {len(centroids)} messages")
    
    if centroids:
        centroids_pt = torch.stack(list(centroids.values()))
        for i, centroid in enumerate(centroids_pt):
            print(f"  Message {i+1}: {msg2str(centroid)}")
    else:
        print("  No messages detected")
    
    print("-" * 40)
# Out:
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /anaconda/envs/watermark/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# ...
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_2858a371363f604153e86fb1c074bf_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_29fe5241becd92fa7665256089c0de_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_355e2452d8c7a92d33aad487227f626_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_71c43518ed80a997f3ba6fdab62a752_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_7896e6d065cc1bc91baded13c8bcef_original.png_multi_wm.png: Found 2 messages
#   Message 1: 10101000001111101001010100000000
#   Message 2: 01101111010111010101101111111111
# ----------------------------------------
# 0_793c55b295aa4f166113e382af613f9_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_7a1619e0bc75743e24fdeb973a5c57c_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_7cbc7ba55704e6a438761433dfde9a6_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 0_8ea318caa183312a7d6ee2e553621c5_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_92f86b5ae1c4ca374550ffe7639ed595_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_9cff3388db5764765f1e87ba2b8118a_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 0_b04e686d34b554cb38f2da9b4a6913fc_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_b07eb98a342d2898962c170bee1b353_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_b1a284c4e0a626628bccf4e371d4bba_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_b234165240bdeed422ff261bdc413264_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_cf31fc10533ad7e5e7944f855557b72c_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101110110000000
# ----------------------------------------
# 0_d0b4bb59821215537715e317edbb_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_d171a4fe0f25a8696e927541742e7af_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_d3e48f2f40a4cfa05d2987f459892e8b_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 0_dd62952d9cfa7f9ae2fefe04f3db5d3_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 0_e66f2fd5adaa3cb66f5811b5e674cd0_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 0_e96e47c2e03cf8716a763af31c5777_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 0_f3bcb825a791d3706f69316549525b_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 0_fe77a5f9f79dccc1e858ef61c582895_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101101010111010101001011111111
# ----------------------------------------
# 10_219bd78f63bcfe691f5ed78e02b73_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_3b9687e77fc6846b2e0f4c849b67f3_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000101111101101010110000000
# ----------------------------------------
# 10_65a45e92a2f782ce5dd5fefb62abd427_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_772ee2318f6d17aff37a9fb410a0d53_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_81b7d34cfb45211ed94d5c10bc3c821f_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_82733db822caaac632a3bc6b21c24c41_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111110111010101001011111111
#   Message 2: 11101000101111101101010110000000
# ----------------------------------------
# 10_958ccafb54734ea2edb49563d968ae1_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_98ace5e81017be929d9a878322b5cfc_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101110010011010001011011110111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_99e9733a7bef9f7ee38665fba5672299_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011011111
# ----------------------------------------
# 10_9ff06c90a45338c29ba380114c7d1a_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_ab85e96b541ddda462c4dc79fcb976b_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_bdd60d0e24457deffa20653b43d7e7_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_be2e12bd4b7290a1989c17965cf05b64_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_bf6ed0795af41da1eb3dc8e3872f47f0_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111110111010101001011111111
# ----------------------------------------
# 10_d411547e77a5b32bbd1ec8e1d2744e4_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_d482caf21095a0be6bf0eff9aaa0156a_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_d5958b3b4144cd3935338367c3dc84aa_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_df3f0c38ba49151ff4ff4987b11de6_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_df52447bc50b4ceab7bf059dfdeaa45_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 10_e3b62438bcffec82c37f5bcbc25f8a38_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_e3d612c98a9e6762127496253c6ceb76_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_e564fb9bdee3b619cd033b5e89dd8a8_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 10_faf0bcc8b26ef944377116b7620967d_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_04ef3e48cc88cb0d1fc4fd94ea88ae1_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_1e01212273277df33ff7aba80ac1e5f_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_257089b973194b74fc80bee7e775578b_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_2e38a4351d509c68714de38caa8be2_original.png_multi_wm.png: Found 2 messages
#   Message 1: 00111000001011101101000110001100
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_3d2a2996ced8314822288debe522aeea_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_449fb6586b9424c0a8414ce7dc5315cf_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_451158d6423e048ea48b72a329cbea2_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_46189a7de5ebe4dd59a177ae16b5920_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_495a1523124a49549c32fa163d1cdc51_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_5f4a76a8e6b6ea18c9615b3796411ea2_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_5f97e214ae0f1a58df7b316536503d_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_624bcfd64b34c095b412996e4646e1fd_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_663699350d4e8683b69ff7847aad8c_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_677b5ffebaaf96bec6a9782632fc66b_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_679ce2e5690b90593fc2948196983_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_67a6b69d410cbae5d6c9e2078d94643_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_702527dbafc89b8aea865c4a86a9fc5e_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_86c2f9a5f0b7567d1c9db25dacc3b3_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_879eb24e5c39aa36476304db1b12d_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_8e64fdf7171e695fc8ca54d3b72891_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_92725fbd178dfafebbda5442edaacef3_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_942df8a5b63da6e03837c2d99de1a1de_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_9e8a7c1a488f274fc0e1b5e4be779dac_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_b18dd5dd8abc837875d4bc11693c344_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 11_b6fee36c36ea6218b46fe64c335f703c_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 11_d666c0b4949b8a9ec66b3f191e71e5c_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
# 12_3fbf972b03315d436dbdebbf75a83a8_original.png_multi_wm.png: Found 2 messages
#   Message 1: 11101000001111101101010110000000
#   Message 2: 01101111010111010101001011111111
# ----------------------------------------
# 13_a1d5e1bdf6f7ba43d825608e26a68052_original.png_multi_wm.png: Found 2 messages
#   Message 1: 01101111010111010101001011111111
#   Message 2: 11101000001111101101010110000000
# ----------------------------------------
